# %% [markdown]
# <a href="https://colab.research.google.com/github/nananatsuki1007/cs1q4-practest/blob/main/cs1q4_practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# it's raining tacos from out of the sky
name = input("what is your name? ")
print("Hi,", name, "!", "I'll be getting your total quiz score, then calculating the average to see if yoou've passed or failed!")
print("You must get at least 75 to pass.")


limit = int(input("How many quiz scores are ya gonna put in? "))

if limit > 1:
  attempt_no = limit - limit

score = int(input("What is your total score? ")), attempt_no == attempt_no + 1

if attempt_no < limit:
 for score in range(attempt_no):
  score = int(input("What is your score? "))
  attempt_no = attempt_no + 1


total = sum(score)
average = total / limit
print("Your average score is", average)

if average >= 75:
  print("YAY!!!!!!!!!!11 You've passed! ")
else:
  print("Sorry, you've failed. :( )")
# Out:
# what is your name? nana
# Hi, nana ! I'll be getting your total quiz score, then calculating the average to see if yoou've passed or failed!
# You must get at least 75 to pass.
# How many quiz scores are ya gonna put in? 3
# What is your total score? 300
# Your average score is 100.0
# YAY!!!!!!!!!!11 You've passed!
